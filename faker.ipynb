# %%
# Generating Fake Data with Python - Using Faker to create a fake dataset
for iii in range(0,50):
    print("-----------------------------------------------------------------------------------------------------------------------------------------------------")    
    print("Post", iii , "Creating --->>>>")
    import requests,random
    from faker import Faker
        
        
    ## Get Users From PostgreSQL
    api_users  = []
    users_url = 'https://fastapi-test1-iozberk.herokuapp.com/users'
    users = requests.get(users_url)
    data = users.json()
    random_login_user = None
    for i in range(1, 21):
        api_users.append(data[i]['email'])

    random_login_user : str = random.choice(api_users)

    # Fake title and content

    faker = Faker('en_US')
    titles = faker.name()
    lorems = faker.paragraph(nb_sentences=3)

    # Login and Authenticate    
    login_url = 'https://fastapi-test1-iozberk.herokuapp.com/login'
    post_url = 'https://fastapi-test1-iozberk.herokuapp.com/posts'

    login_payload = {'username': f'{random_login_user}','password':'Password1!'}
    login_response = requests.post(login_url,data= login_payload)
    access_token = login_response.json()["access_token"]
    # print("Token: ", access_token)

    # Post Fake Data

    post_payload = {'title': f'{titles}','content': f'{lorems}', 'published': random.choice([True, False])}
    headers = {'Authorization': 'Bearer ' + access_token}
    post_response = requests.post(post_url,json= post_payload, headers=headers)

    print("Response: ", post_response.json())
    print("Post", iii , "Created !!!")
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 0 Creating --->>>>
# Response:  {'title': 'Mrs. Laurie Archer', 'content': 'Hear hospital effort store current nor many. Yet television ten federal teacher the.', 'published': True, 'id': 410, 'created_at': '2022-08-15T21:08:17.090296+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 0 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 1 Creating --->>>>
# Response:  {'title': 'Janice Mcmahon', 'content': 'Wonder art station line despite late collection own. Certain wide give front manager course avoid.', 'published': False, 'id': 411, 'created_at': '2022-08-15T21:08:19.748754+00:00', 'owner_id': 7, 'owner': {'id': 7, 'email': 'fastapi12345@fastapi.com', 'created_at': '2022-08-15T10:38:56.162195+00:00'}}
# Post 1 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 2 Creating --->>>>
# Response:  {'title': 'Daniel Shaffer', 'content': 'Air hundred clear tough moment soldier around. Agent meet figure nearly lose physical administration culture.', 'published': False, 'id': 412, 'created_at': '2022-08-15T21:08:22.474496+00:00', 'owner_id': 4, 'owner': {'id': 4, 'email': 'fastapi12@fastapi.com', 'created_at': '2022-08-15T10:38:51.082905+00:00'}}
# Post 2 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 3 Creating --->>>>
# Response:  {'title': 'Anthony Cisneros', 'content': 'Protect style others response fly trouble Republican. Game quite own key newspaper theory. Allow half indicate present possible single.', 'published': True, 'id': 413, 'created_at': '2022-08-15T21:08:25.508595+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# Post 3 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 4 Creating --->>>>
# Response:  {'title': 'Victoria Cortez', 'content': 'Natural road last sign government company already. Remain so expert southern ball.', 'published': True, 'id': 414, 'created_at': '2022-08-15T21:08:28.604707+00:00', 'owner_id': 4, 'owner': {'id': 4, 'email': 'fastapi12@fastapi.com', 'created_at': '2022-08-15T10:38:51.082905+00:00'}}
# Post 4 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 5 Creating --->>>>
# Response:  {'title': 'Brandy Patterson DDS', 'content': 'White common author hot. Me bar so provide old.', 'published': False, 'id': 415, 'created_at': '2022-08-15T21:08:31.515151+00:00', 'owner_id': 18, 'owner': {'id': 18, 'email': 'user6@python.com', 'created_at': '2022-08-15T20:56:42.880653+00:00'}}
# Post 5 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 6 Creating --->>>>
# Response:  {'title': 'Alan Larsen', 'content': 'Cost of part American conference. Include that real share computer politics.', 'published': False, 'id': 416, 'created_at': '2022-08-15T21:08:34.509279+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# Post 6 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 7 Creating --->>>>
# Response:  {'title': 'Kelly Carter', 'content': 'Prove theory bring computer show church. Us fill analysis hope safe picture.', 'published': True, 'id': 417, 'created_at': '2022-08-15T21:08:37.405924+00:00', 'owner_id': 21, 'owner': {'id': 21, 'email': 'user9@python.com', 'created_at': '2022-08-15T20:56:52.621254+00:00'}}
# Post 7 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 8 Creating --->>>>
# Response:  {'title': 'Jonathan Davis', 'content': 'Do consumer bed color station old. Bar avoid positive someone attorney off human eat.', 'published': True, 'id': 418, 'created_at': '2022-08-15T21:08:39.899057+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# Post 8 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 9 Creating --->>>>
# Response:  {'title': 'Brian Gilbert', 'content': 'My others order director and support. Ahead suffer process radio. Project boy some away.', 'published': True, 'id': 419, 'created_at': '2022-08-15T21:08:42.739481+00:00', 'owner_id': 18, 'owner': {'id': 18, 'email': 'user6@python.com', 'created_at': '2022-08-15T20:56:42.880653+00:00'}}
# Post 9 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 10 Creating --->>>>
# Response:  {'title': 'Courtney Williams', 'content': 'Special current each certainly. Region crime son yes bad. Life prove movement film.', 'published': False, 'id': 420, 'created_at': '2022-08-15T21:08:45.576429+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# Post 10 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 11 Creating --->>>>
# Response:  {'title': 'Charles White', 'content': 'Positive fast fight direction challenge. Around commercial price.', 'published': True, 'id': 421, 'created_at': '2022-08-15T21:08:48.448809+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 11 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 12 Creating --->>>>
# Response:  {'title': 'Becky Wood', 'content': 'Environment citizen size author. Letter fast yes ground everything develop role.', 'published': True, 'id': 422, 'created_at': '2022-08-15T21:08:51.181485+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# Post 12 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 13 Creating --->>>>
# Response:  {'title': 'David Cruz', 'content': 'Baby social successful fight. End song opportunity population myself itself man. Sell present community direction today best skin.', 'published': True, 'id': 423, 'created_at': '2022-08-15T21:08:54.269979+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# Post 13 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 14 Creating --->>>>
# Response:  {'title': 'Christopher Choi', 'content': 'Story choice however tax. Return do may. Perform read production win.', 'published': True, 'id': 424, 'created_at': '2022-08-15T21:08:58.558534+00:00', 'owner_id': 20, 'owner': {'id': 20, 'email': 'user8@python.com', 'created_at': '2022-08-15T20:56:49.785169+00:00'}}
# Post 14 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 15 Creating --->>>>
# Response:  {'title': 'Henry Young', 'content': 'Stay parent behavior each data money fall. In decade explain security light cost eat after.', 'published': False, 'id': 425, 'created_at': '2022-08-15T21:09:01.565154+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# Post 15 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 16 Creating --->>>>
# Response:  {'title': 'Kristin Medina', 'content': 'Event result along after. Recent hotel population husband impact particular central. Happen author civil stage possible.', 'published': False, 'id': 426, 'created_at': '2022-08-15T21:09:04.488809+00:00', 'owner_id': 9, 'owner': {'id': 9, 'email': 'fastapi1234567@fastapi.com', 'created_at': '2022-08-15T10:38:59.880611+00:00'}}
# Post 16 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 17 Creating --->>>>
# Response:  {'title': 'Joseph Vaughan', 'content': 'Year toward design. Heavy degree wonder make. Could consumer help area piece.', 'published': False, 'id': 427, 'created_at': '2022-08-15T21:09:08.185650+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# Post 17 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 18 Creating --->>>>
# Response:  {'title': 'Anne Chandler', 'content': 'Speech reason shoulder after control these short. Modern deep particularly indicate small. Risk million international he.', 'published': True, 'id': 428, 'created_at': '2022-08-15T21:09:11.198976+00:00', 'owner_id': 5, 'owner': {'id': 5, 'email': 'fastapi123@fastapi.com', 'created_at': '2022-08-15T10:38:52.819474+00:00'}}
# Post 18 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 19 Creating --->>>>
# Response:  {'title': 'Amy Ramos', 'content': 'Story the partner positive single produce almost. Sister yet fast force. Site class class at former wife.', 'published': True, 'id': 429, 'created_at': '2022-08-15T21:09:14.087615+00:00', 'owner_id': 8, 'owner': {'id': 8, 'email': 'fastapi123456@fastapi.com', 'created_at': '2022-08-15T10:38:58.133098+00:00'}}
# Post 19 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 20 Creating --->>>>
# Response:  {'title': 'Kristy Davidson DVM', 'content': 'Realize class accept main doctor ability security. Marriage nation way may recent. As enter camera special national.', 'published': True, 'id': 430, 'created_at': '2022-08-15T21:09:18.220957+00:00', 'owner_id': 7, 'owner': {'id': 7, 'email': 'fastapi12345@fastapi.com', 'created_at': '2022-08-15T10:38:56.162195+00:00'}}
# Post 20 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 21 Creating --->>>>
# Response:  {'title': 'John Larson', 'content': 'Pass culture sound media through western understand. Blue remember account several thank. East choice mind discussion.', 'published': True, 'id': 431, 'created_at': '2022-08-15T21:09:21.258242+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# Post 21 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 22 Creating --->>>>
# Response:  {'title': 'Jeffrey Bell', 'content': 'He agreement special hotel develop. Nothing chance community special popular do.', 'published': True, 'id': 432, 'created_at': '2022-08-15T21:09:24.080169+00:00', 'owner_id': 13, 'owner': {'id': 13, 'email': 'user1@python.com', 'created_at': '2022-08-15T20:56:33.530426+00:00'}}
# Post 22 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 23 Creating --->>>>
# Response:  {'title': 'Cynthia Valencia', 'content': 'Game thing trade article. Put entire PM able partner across. Sense decade hear wide their south between.', 'published': False, 'id': 433, 'created_at': '2022-08-15T21:09:26.980868+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# Post 23 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 24 Creating --->>>>
# Response:  {'title': 'Max Carson', 'content': 'Skill white play affect significant entire away. Executive road us back.', 'published': False, 'id': 434, 'created_at': '2022-08-15T21:09:29.578848+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# Post 24 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 25 Creating --->>>>
# Response:  {'title': 'Daniel Ballard', 'content': 'All herself degree. Occur occur travel beyond. For Mr forget involve well interest.', 'published': True, 'id': 435, 'created_at': '2022-08-15T21:09:32.263160+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 25 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 26 Creating --->>>>
# Response:  {'title': 'Lisa Mejia', 'content': 'Discover picture defense.', 'published': False, 'id': 436, 'created_at': '2022-08-15T21:09:35.008739+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# Post 26 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 27 Creating --->>>>
# Response:  {'title': 'Brian Zavala', 'content': 'Peace early none many house often. Resource season audience should oil its.', 'published': True, 'id': 437, 'created_at': '2022-08-15T21:09:38.404330+00:00', 'owner_id': 13, 'owner': {'id': 13, 'email': 'user1@python.com', 'created_at': '2022-08-15T20:56:33.530426+00:00'}}
# Post 27 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 28 Creating --->>>>
# Response:  {'title': 'Candace Ortiz', 'content': 'They against song happen Congress friend green near. Consider research majority type girl control.', 'published': False, 'id': 438, 'created_at': '2022-08-15T21:09:41.270686+00:00', 'owner_id': 14, 'owner': {'id': 14, 'email': 'user2@python.com', 'created_at': '2022-08-15T20:56:35.813352+00:00'}}
# Post 28 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 29 Creating --->>>>
# Response:  {'title': 'Karen Blankenship', 'content': 'List during draw.', 'published': False, 'id': 439, 'created_at': '2022-08-15T21:09:43.924332+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# Post 29 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 30 Creating --->>>>
# Response:  {'title': 'Larry Anderson', 'content': 'Miss Mr effect media. Interesting eat be air. Yard hard stock fish.', 'published': False, 'id': 440, 'created_at': '2022-08-15T21:09:46.789213+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# Post 30 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 31 Creating --->>>>
# Response:  {'title': 'Yolanda Jackson', 'content': 'Nearly born herself how interest oil. First himself idea behind.', 'published': True, 'id': 441, 'created_at': '2022-08-15T21:09:49.720923+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 31 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 32 Creating --->>>>
# Response:  {'title': 'Emily Henry', 'content': 'Pull think maintain camera two enter. Quickly near discuss pressure. Avoid Congress list community.', 'published': True, 'id': 442, 'created_at': '2022-08-15T21:09:52.432629+00:00', 'owner_id': 18, 'owner': {'id': 18, 'email': 'user6@python.com', 'created_at': '2022-08-15T20:56:42.880653+00:00'}}
# Post 32 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 33 Creating --->>>>
# Response:  {'title': 'Nancy Price', 'content': 'Player any dark audience. Generation community ball of instead.', 'published': False, 'id': 443, 'created_at': '2022-08-15T21:09:55.401656+00:00', 'owner_id': 5, 'owner': {'id': 5, 'email': 'fastapi123@fastapi.com', 'created_at': '2022-08-15T10:38:52.819474+00:00'}}
# Post 33 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 34 Creating --->>>>
# Response:  {'title': 'Whitney Wheeler', 'content': 'Bit dinner join ahead church responsibility. Star boy move skill effect might people. Family I history exist. Along sure edge arrive table similar bed.', 'published': False, 'id': 444, 'created_at': '2022-08-15T21:09:58.480717+00:00', 'owner_id': 9, 'owner': {'id': 9, 'email': 'fastapi1234567@fastapi.com', 'created_at': '2022-08-15T10:38:59.880611+00:00'}}
# Post 34 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 35 Creating --->>>>
# Response:  {'title': 'Holly Ponce', 'content': 'Citizen detail quickly involve year already partner. Finally wear each five idea authority position. Site bed foot opportunity mouth present.', 'published': True, 'id': 445, 'created_at': '2022-08-15T21:10:01.449347+00:00', 'owner_id': 2, 'owner': {'id': 2, 'email': 'fastapi1@fastapi.com', 'created_at': '2022-08-15T10:38:41.136259+00:00'}}
# Post 35 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 36 Creating --->>>>
# Response:  {'title': 'Sean Nielsen', 'content': 'Admit improve sport. Able how white visit. Account short space morning movement stay skill.', 'published': True, 'id': 446, 'created_at': '2022-08-15T21:10:04.421089+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 36 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 37 Creating --->>>>
# Response:  {'title': 'John Mcguire', 'content': 'Here ever would reveal all leg west pick. Ok see civil forward simply less campaign.', 'published': False, 'id': 447, 'created_at': '2022-08-15T21:10:07.316241+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# Post 37 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 38 Creating --->>>>
# Response:  {'title': 'Jennifer Hernandez', 'content': 'Arm require open popular probably play. Center your check if boy goal develop. Agent matter mother seem medical goal.', 'published': False, 'id': 448, 'created_at': '2022-08-15T21:10:10.237633+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# Post 38 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 39 Creating --->>>>
# Response:  {'title': 'Kimberly Rosales', 'content': 'Half very table through item. Risk value two technology. Industry issue new quite threat few.', 'published': True, 'id': 449, 'created_at': '2022-08-15T21:10:13.121613+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# Post 39 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 40 Creating --->>>>
# Response:  {'title': 'Lynn Jackson', 'content': 'Charge director compare might field meet. Sit today book. City bar center these total.', 'published': True, 'id': 450, 'created_at': '2022-08-15T21:10:16.192723+00:00', 'owner_id': 2, 'owner': {'id': 2, 'email': 'fastapi1@fastapi.com', 'created_at': '2022-08-15T10:38:41.136259+00:00'}}
# Post 40 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 41 Creating --->>>>
# Response:  {'title': 'Jill Chavez', 'content': 'Administration main project. Explain out purpose whole place I item. From land population fly season success foreign however.', 'published': False, 'id': 451, 'created_at': '2022-08-15T21:10:19.356045+00:00', 'owner_id': 8, 'owner': {'id': 8, 'email': 'fastapi123456@fastapi.com', 'created_at': '2022-08-15T10:38:58.133098+00:00'}}
# Post 41 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 42 Creating --->>>>
# Response:  {'title': 'Thomas Mahoney', 'content': 'Moment travel look ready TV information black. Yes find wait.', 'published': False, 'id': 452, 'created_at': '2022-08-15T21:10:22.207646+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 42 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 43 Creating --->>>>
# Response:  {'title': 'Justin Anthony', 'content': 'Middle in happen health learn west happy. Agent matter design prevent memory capital.', 'published': False, 'id': 453, 'created_at': '2022-08-15T21:10:25.395437+00:00', 'owner_id': 4, 'owner': {'id': 4, 'email': 'fastapi12@fastapi.com', 'created_at': '2022-08-15T10:38:51.082905+00:00'}}
# Post 43 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 44 Creating --->>>>
# Response:  {'title': 'Robert Foster', 'content': 'Case change style human. Modern stop blood listen poor draw century.', 'published': False, 'id': 454, 'created_at': '2022-08-15T21:10:28.293805+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# Post 44 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 45 Creating --->>>>
# Response:  {'title': 'Robin Watson', 'content': 'Study window activity born alone. Decision camera I write.', 'published': False, 'id': 455, 'created_at': '2022-08-15T21:10:31.111454+00:00', 'owner_id': 15, 'owner': {'id': 15, 'email': 'user3@python.com', 'created_at': '2022-08-15T20:56:37.479528+00:00'}}
# Post 45 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 46 Creating --->>>>
# Response:  {'title': 'Kristin Thomas', 'content': 'So defense live. Garden rather form ready. Same practice four stay would unit nearly.', 'published': False, 'id': 456, 'created_at': '2022-08-15T21:10:33.847311+00:00', 'owner_id': 21, 'owner': {'id': 21, 'email': 'user9@python.com', 'created_at': '2022-08-15T20:56:52.621254+00:00'}}
# Post 46 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 47 Creating --->>>>
# Response:  {'title': 'Cynthia Jackson', 'content': 'Another not education. Quite improve kitchen hit imagine. Make can these.', 'published': False, 'id': 457, 'created_at': '2022-08-15T21:10:36.962081+00:00', 'owner_id': 15, 'owner': {'id': 15, 'email': 'user3@python.com', 'created_at': '2022-08-15T20:56:37.479528+00:00'}}
# Post 47 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 48 Creating --->>>>
# Response:  {'title': 'Richard Singh', 'content': 'Role amount night find. Drive public food range Republican value effect. Notice market building hot style might evidence into.', 'published': False, 'id': 458, 'created_at': '2022-08-15T21:10:39.625146+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# Post 48 Created !!!
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Post 49 Creating --->>>>
# Response:  {'title': 'Laura Mcconnell', 'content': 'Various south certain news particularly system. Development edge people figure. Group example although study role.', 'published': True, 'id': 459, 'created_at': '2022-08-15T21:10:42.448852+00:00', 'owner_id': 20, 'owner': {'id': 20, 'email': 'user8@python.com', 'created_at': '2022-08-15T20:56:49.785169+00:00'}}
# Post 49 Created !!!
