# %%
# Generating Fake Data with Python - Using Faker to create a fake dataset
for iii in range(1,3000):

    import requests,random
    from faker import Faker
        
        
    ## Get Users From PostgreSQL
    api_users  = []
    users_url = 'https://fastapi-test1-iozberk.herokuapp.com/users'
    users = requests.get(users_url)
    data = users.json()
    random_login_user = None
    for i in range(1, 21):
        api_users.append(data[i]['email'])

    random_login_user : str = random.choice(api_users)
    print(random_login_user)

    # Fake title and content

    faker = Faker('en_US')
    titles = faker.name()
    lorems = faker.paragraph(nb_sentences=3)

    # Login and Authenticate    
    login_url = 'https://fastapi-test1-iozberk.herokuapp.com/login'
    post_url = 'https://fastapi-test1-iozberk.herokuapp.com/posts'

    login_payload = {'username': f'{random_login_user}','password':'Password1!'}
    login_response = requests.post(login_url,data= login_payload)
    access_token = login_response.json()["access_token"]
    print("UserName: " ,random_login_user, " " , access_token)

    # Post Fake Data

    post_payload = {'title': f'{titles}','content': f'{lorems}', 'published': random.choice([True, False])}
    headers = {'Authorization': 'Bearer ' + access_token}
    post_response = requests.post(post_url,json= post_payload, headers=headers)

    print("Post Response: ", post_response.json())
    print(iii , " - Post Created")
# Out:
# fastapi123456789@fastapi.com
# UserName:  fastapi123456789@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMSwiZXhwIjoxNjYwNjAwNjI1fQ.JeLEcW9s9Mlpa7DeWQj60xFP6MHChOVQRvYOGEtvOfo
# Post Response:  {'title': 'Alexander Smith', 'content': 'Writer manager statement number everyone. Imagine religious course would seek consider item despite. Push protect huge wall house himself. Art director herself true common.', 'published': True, 'id': 359, 'created_at': '2022-08-15T20:57:06.073373+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# 1  - Post Created
# fastapi12345678@fastapi.com
# UserName:  fastapi12345678@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMCwiZXhwIjoxNjYwNjAwNjI4fQ.W66kIdmaEOSP0NSJBy6nriT9ZJF5Cr1goCKPnZVo_a8
# Post Response:  {'title': 'Katrina Diaz', 'content': 'Down head class. Between myself better lose guy prepare civil. Condition join record car fear measure south.', 'published': False, 'id': 360, 'created_at': '2022-08-15T20:57:08.937494+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# 2  - Post Created
# fastapi123@fastapi.com
# UserName:  fastapi123@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo1LCJleHAiOjE2NjA2MDA2MzB9.xZ9PP4TuUFwvCHMPXvElypC29135t0pflDzGxtdmlW8
# Post Response:  {'title': 'Colin Sweeney', 'content': 'History toward board the. Federal few building result interesting second here.', 'published': False, 'id': 361, 'created_at': '2022-08-15T20:57:11.706089+00:00', 'owner_id': 5, 'owner': {'id': 5, 'email': 'fastapi123@fastapi.com', 'created_at': '2022-08-15T10:38:52.819474+00:00'}}
# 3  - Post Created
# user4@python.com
# UserName:  user4@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNiwiZXhwIjoxNjYwNjAwNjMzfQ.QO97ttY0uaa9wIrFBPon8kU4r93a5V8rrYDOTOXy1X4
# Post Response:  {'title': 'William Jones', 'content': 'Read dinner be certainly property.', 'published': True, 'id': 362, 'created_at': '2022-08-15T20:57:14.550674+00:00', 'owner_id': 16, 'owner': {'id': 16, 'email': 'user4@python.com', 'created_at': '2022-08-15T20:56:39.201247+00:00'}}
# 4  - Post Created
# user9@python.com
# UserName:  user9@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoyMSwiZXhwIjoxNjYwNjAwNjM2fQ.64YKTkxuzeUB0BGuzl-13z-Rbhhm2XqC2ezJAJYr4H4
# Post Response:  {'title': 'Amy Campbell', 'content': 'International order herself new and rich attack serve. Ask increase particular scene set.', 'published': True, 'id': 363, 'created_at': '2022-08-15T20:57:17.530498+00:00', 'owner_id': 21, 'owner': {'id': 21, 'email': 'user9@python.com', 'created_at': '2022-08-15T20:56:52.621254+00:00'}}
# 5  - Post Created
# fastapi1234@fastapi.com
# UserName:  fastapi1234@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo2LCJleHAiOjE2NjA2MDA2Mzl9.M2mnTfVdnqox-Dk5_XHdU-BR4uiJKAlFPs_kZllZWao
# Post Response:  {'title': 'Jamie Matthews', 'content': 'Make few likely. We that about executive. Price wife despite work.', 'published': False, 'id': 364, 'created_at': '2022-08-15T20:57:20.286651+00:00', 'owner_id': 6, 'owner': {'id': 6, 'email': 'fastapi1234@fastapi.com', 'created_at': '2022-08-15T10:38:54.531018+00:00'}}
# 6  - Post Created
# fastapi123456789@fastapi.com
# UserName:  fastapi123456789@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMSwiZXhwIjoxNjYwNjAwNjQyfQ.drh9pvHTpe6uSwHuO7HEQJuCmI32xok9pN2ICoAy5PM
# Post Response:  {'title': 'Sonya Bowman MD', 'content': 'Time member color southern. Hold still professional key. Cultural at care share sit interesting television.', 'published': True, 'id': 365, 'created_at': '2022-08-15T20:57:22.955438+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# 7  - Post Created
# fastapi123456789@fastapi.com
# UserName:  fastapi123456789@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMSwiZXhwIjoxNjYwNjAwNjQ1fQ.fpQ_k34pJQz2Cgalhqno8oVoakxzTcZXoaqFha1qiFg
# Post Response:  {'title': 'Sara Dunn', 'content': 'Report nearly help them response seat. Success list campaign happen. Record right conference tonight fight study.', 'published': False, 'id': 366, 'created_at': '2022-08-15T20:57:26.132584+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# 8  - Post Created
# user8@python.com
# UserName:  user8@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoyMCwiZXhwIjoxNjYwNjAwNjQ4fQ.l2JQkNJTwVlI4dxRJtFO__mmCDMAHvJJwnM_rIOSpCs
# Post Response:  {'title': 'Kelly Alvarez', 'content': 'Trade ready face. Upon TV police officer security. Every focus close into upon action challenge protect.', 'published': False, 'id': 367, 'created_at': '2022-08-15T20:57:28.894701+00:00', 'owner_id': 20, 'owner': {'id': 20, 'email': 'user8@python.com', 'created_at': '2022-08-15T20:56:49.785169+00:00'}}
# 9  - Post Created
# user7@python.com
# UserName:  user7@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxOSwiZXhwIjoxNjYwNjAwNjUwfQ.yCd37jCFqO8PLw2dKMGRGcsJRG8xiwHdY7-ob76AlJ0
# Post Response:  {'title': 'Heather Simmons', 'content': 'Structure one prepare organization. Leave world science reflect. Network language suffer land lot final safe pull.', 'published': False, 'id': 368, 'created_at': '2022-08-15T20:57:31.984455+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# 10  - Post Created
# user@python.com
# UserName:  user@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMiwiZXhwIjoxNjYwNjAwNjU0fQ.9l-NjEWU6oZ7SpEtsbjPwfVXQOBa5U93ssaitmHgbe8
# Post Response:  {'title': 'Mr. Ethan Tucker', 'content': 'Parent story six degree. Camera open always share man. Same former picture western ability woman.', 'published': True, 'id': 369, 'created_at': '2022-08-15T20:57:35.072819+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# 11  - Post Created
# user8@python.com
# UserName:  user8@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoyMCwiZXhwIjoxNjYwNjAwNjU3fQ.Rosqw6UY5OlcbWs5lO9iihBCBrc6yoNCbwBUeCB8-F8
# Post Response:  {'title': 'Donald Jennings', 'content': 'Determine reflect onto prepare those admit. Stage report hear contain heavy upon.', 'published': True, 'id': 370, 'created_at': '2022-08-15T20:57:37.908433+00:00', 'owner_id': 20, 'owner': {'id': 20, 'email': 'user8@python.com', 'created_at': '2022-08-15T20:56:49.785169+00:00'}}
# 12  - Post Created
# user3@python.com
# UserName:  user3@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNSwiZXhwIjoxNjYwNjAwNjU5fQ.ERTFi6fGfzLNkdUgTK5iHbHb8HUwOVl-rCcT1-0vGvs
# Post Response:  {'title': 'Rhonda Stevenson', 'content': 'Four free behind condition themselves couple. Red about perhaps green score science door. Mr force past occur.', 'published': True, 'id': 371, 'created_at': '2022-08-15T20:57:40.569885+00:00', 'owner_id': 15, 'owner': {'id': 15, 'email': 'user3@python.com', 'created_at': '2022-08-15T20:56:37.479528+00:00'}}
# 13  - Post Created
# fastapi123456789@fastapi.com
# UserName:  fastapi123456789@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMSwiZXhwIjoxNjYwNjAwNjYyfQ.3Va_fTPohDVkaK-cYQU9VTCClNGY03rF0JAxTQAWEfo
# Post Response:  {'title': 'Andrew Morris', 'content': 'Would lose stock support. Give own note along play crime produce.', 'published': False, 'id': 372, 'created_at': '2022-08-15T20:57:43.280845+00:00', 'owner_id': 11, 'owner': {'id': 11, 'email': 'fastapi123456789@fastapi.com', 'created_at': '2022-08-15T10:39:06.459194+00:00'}}
# 14  - Post Created
# fastapi@fastapi.com
# UserName:  fastapi@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjozLCJleHAiOjE2NjA2MDA2NjV9.iP8Ud0pK-IGfu5uB3LWrJrriegMCTWq44t_soez5acY
# Post Response:  {'title': 'Natalie Stone', 'content': 'Agree about compare guess manager never similar.', 'published': False, 'id': 373, 'created_at': '2022-08-15T20:57:46.318516+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# 15  - Post Created
# user6@python.com
# UserName:  user6@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxOCwiZXhwIjoxNjYwNjAwNjY4fQ.FnqEjfk-uEWGBRXY1Ci3XGFK0Brlbmh1QowyrCTsG7A
# Post Response:  {'title': 'Timothy Casey', 'content': 'Yes hard clear they. Spend agree his performance watch sign than. Strategy both check professional church nothing by it.', 'published': True, 'id': 374, 'created_at': '2022-08-15T20:57:49.183782+00:00', 'owner_id': 18, 'owner': {'id': 18, 'email': 'user6@python.com', 'created_at': '2022-08-15T20:56:42.880653+00:00'}}
# 16  - Post Created
# user4@python.com
# UserName:  user4@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNiwiZXhwIjoxNjYwNjAwNjcxfQ.qQBcmUZYwTVE2cuI_IzhoSseCBNBgPnVn-zE47X74tU
# Post Response:  {'title': 'Jacob Crawford', 'content': 'Cover thank concern action. Music others administration unit recent rise.', 'published': True, 'id': 375, 'created_at': '2022-08-15T20:57:52.051225+00:00', 'owner_id': 16, 'owner': {'id': 16, 'email': 'user4@python.com', 'created_at': '2022-08-15T20:56:39.201247+00:00'}}
# 17  - Post Created
# fastapi@fastapi.com
# UserName:  fastapi@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjozLCJleHAiOjE2NjA2MDA2NzN9.kq_M_CxEOUsd2eO7bihF5hTmiAcI_Bndw0dBYDj2ulc
# Post Response:  {'title': 'Ashley Hunter', 'content': 'Others boy such bar always. Force course box campaign difference system rate myself.', 'published': False, 'id': 376, 'created_at': '2022-08-15T20:57:54.720842+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# 18  - Post Created
# fastapi12345678@fastapi.com
# UserName:  fastapi12345678@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMCwiZXhwIjoxNjYwNjAwNjc2fQ.TfzIjw1AQwWzzSrNd7ys1CDpG2DydqAI7sdVoU8can8
# Post Response:  {'title': 'Carlos Stanley', 'content': 'Station check condition maintain strategy career. Ready really girl. Each once explain very perhaps rock. South up charge else that suffer should.', 'published': True, 'id': 377, 'created_at': '2022-08-15T20:57:57.561938+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# 19  - Post Created
# user1@python.com
# UserName:  user1@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMywiZXhwIjoxNjYwNjAwNjc5fQ.mOhilZCE778Qdlezpe9q9cV6Vd9gj39kdgyKgrf2yVE
# Post Response:  {'title': 'Sarah Alvarez', 'content': 'Road east participant nice home pretty. Various computer effort between collection talk.', 'published': False, 'id': 378, 'created_at': '2022-08-15T20:58:00.079389+00:00', 'owner_id': 13, 'owner': {'id': 13, 'email': 'user1@python.com', 'created_at': '2022-08-15T20:56:33.530426+00:00'}}
# 20  - Post Created
# user7@python.com
# UserName:  user7@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxOSwiZXhwIjoxNjYwNjAwNjgxfQ.2GFH14tMecp9Obt6TVcaqR9wZFhz-VQgS43z1F1JESc
# Post Response:  {'title': 'Sharon Gutierrez', 'content': 'Still successful south risk tough. Film marriage write in idea huge. Bring fly approach.', 'published': False, 'id': 379, 'created_at': '2022-08-15T20:58:02.595399+00:00', 'owner_id': 19, 'owner': {'id': 19, 'email': 'user7@python.com', 'created_at': '2022-08-15T20:56:48.075358+00:00'}}
# 21  - Post Created
# user5@python.com
# UserName:  user5@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNywiZXhwIjoxNjYwNjAwNjg0fQ.J60e2EkgsrMNuyaXsfM1qQxxBWvVXAApZe1y4mkXwC8
# Post Response:  {'title': 'Gabriel Jones', 'content': 'Subject particular bit economic. Discuss beyond hit every single. Difficult yard age.', 'published': True, 'id': 380, 'created_at': '2022-08-15T20:58:05.460161+00:00', 'owner_id': 17, 'owner': {'id': 17, 'email': 'user5@python.com', 'created_at': '2022-08-15T20:56:41.020125+00:00'}}
# 22  - Post Created
# user@python.com
# UserName:  user@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMiwiZXhwIjoxNjYwNjAwNjg3fQ.Ou8acA69-7662Y-eM9e2PN92sCB72rqUvgTgLjipr8o
# Post Response:  {'title': 'Kayla Adams', 'content': 'Data experience as term develop. Age series series the.', 'published': True, 'id': 381, 'created_at': '2022-08-15T20:58:08.327591+00:00', 'owner_id': 12, 'owner': {'id': 12, 'email': 'user@python.com', 'created_at': '2022-08-15T20:56:29.584691+00:00'}}
# 23  - Post Created
# fastapi1234567@fastapi.com
# UserName:  fastapi1234567@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo5LCJleHAiOjE2NjA2MDA2OTB9.eZRtxeyZ4RyZjTWXSQR-xGkmkxlBjYGbmBSIDta49kA
# Post Response:  {'title': 'Jessica Reyes', 'content': 'Career popular account shake cultural state itself. Yard mission suggest site. Feeling level his create economic specific apply staff.', 'published': False, 'id': 382, 'created_at': '2022-08-15T20:58:11.195208+00:00', 'owner_id': 9, 'owner': {'id': 9, 'email': 'fastapi1234567@fastapi.com', 'created_at': '2022-08-15T10:38:59.880611+00:00'}}
# 24  - Post Created
# fastapi123456@fastapi.com
# UserName:  fastapi123456@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo4LCJleHAiOjE2NjA2MDA2OTN9.mocyrddqH0nQoXP6MfiZCe-WSoKE6s1NXmuOv6BxSK4
# Post Response:  {'title': 'Michael Flowers', 'content': 'Drop recent prevent. Family along community whose. Individual reach four brother other tree away. Popular scientist any turn blue college.', 'published': True, 'id': 383, 'created_at': '2022-08-15T20:58:14.002731+00:00', 'owner_id': 8, 'owner': {'id': 8, 'email': 'fastapi123456@fastapi.com', 'created_at': '2022-08-15T10:38:58.133098+00:00'}}
# 25  - Post Created
# user2@python.com
# UserName:  user2@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNCwiZXhwIjoxNjYwNjAwNjk1fQ.UtlJW6xCEnn10tTkRjRcGr0qVy5ycsEO55ZELkn7vAM
# Post Response:  {'title': 'Patricia Baker', 'content': 'Color between skill admit reflect. Hit doctor both change. Main traditional person administration.', 'published': False, 'id': 384, 'created_at': '2022-08-15T20:58:16.815779+00:00', 'owner_id': 14, 'owner': {'id': 14, 'email': 'user2@python.com', 'created_at': '2022-08-15T20:56:35.813352+00:00'}}
# 26  - Post Created
# fastapi@fastapi.com
# UserName:  fastapi@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjozLCJleHAiOjE2NjA2MDA2OTh9.5l-XSo7LxxDhsWZwxnwK9pQOD7vxbQcf8m17ySMZ7JU
# Post Response:  {'title': 'Janice Foley', 'content': 'What sign memory name become. Say professional within allow eat position.', 'published': False, 'id': 385, 'created_at': '2022-08-15T20:58:19.786003+00:00', 'owner_id': 3, 'owner': {'id': 3, 'email': 'fastapi@fastapi.com', 'created_at': '2022-08-15T10:38:49.306793+00:00'}}
# 27  - Post Created
# user8@python.com
# UserName:  user8@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoyMCwiZXhwIjoxNjYwNjAwNzAxfQ.K1BOl_1iCPDT159gxYOvrlj4-uNAQ50e8B7VUtF5ufc
# Post Response:  {'title': 'Nicole Jacobs', 'content': 'Baby figure home officer son walk house. Get what Democrat support.', 'published': True, 'id': 386, 'created_at': '2022-08-15T20:58:22.864049+00:00', 'owner_id': 20, 'owner': {'id': 20, 'email': 'user8@python.com', 'created_at': '2022-08-15T20:56:49.785169+00:00'}}
# 28  - Post Created
# fastapi12345678@fastapi.com
# UserName:  fastapi12345678@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxMCwiZXhwIjoxNjYwNjAwNzA0fQ.0BP5JjWVvLYejEHSKS-lsOF0Hy-YIPIv0E0yvvKjt14
# Post Response:  {'title': 'Paula Flynn', 'content': 'Could carry especially just.', 'published': False, 'id': 387, 'created_at': '2022-08-15T20:58:25.630779+00:00', 'owner_id': 10, 'owner': {'id': 10, 'email': 'fastapi12345678@fastapi.com', 'created_at': '2022-08-15T10:39:04.662813+00:00'}}
# 29  - Post Created
# fastapi1234@fastapi.com
# UserName:  fastapi1234@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo2LCJleHAiOjE2NjA2MDA3MDd9.1iMBTa7fwU_VigIiCSYbfxzIdX7ms0tjLle9o00zNSQ
# Post Response:  {'title': 'John Nelson', 'content': 'Whom pick very southern thus he. Better turn factor detail.', 'published': True, 'id': 388, 'created_at': '2022-08-15T20:58:28.454203+00:00', 'owner_id': 6, 'owner': {'id': 6, 'email': 'fastapi1234@fastapi.com', 'created_at': '2022-08-15T10:38:54.531018+00:00'}}
# 30  - Post Created
# fastapi123456@fastapi.com
# UserName:  fastapi123456@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo4LCJleHAiOjE2NjA2MDA3MTB9.d82YIu6QogWwwRN3RnmzGTXpB7rQtAk4eu8CVYxqz04
# Post Response:  {'title': 'Leslie Lee', 'content': 'Person cultural item national seem. Of perform something production shake. Easy popular away war word if light.', 'published': True, 'id': 389, 'created_at': '2022-08-15T20:58:31.192682+00:00', 'owner_id': 8, 'owner': {'id': 8, 'email': 'fastapi123456@fastapi.com', 'created_at': '2022-08-15T10:38:58.133098+00:00'}}
# 31  - Post Created
# fastapi12@fastapi.com
# UserName:  fastapi12@fastapi.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjo0LCJleHAiOjE2NjA2MDA3MTJ9.CN1QJuV5ZzLVxptfrtH26RkU6LIpyQdRDr2bZPtQoek
# Post Response:  {'title': 'Michael Walker', 'content': 'Successful they set red accept popular line. Member must memory resource policy. Moment thus bar smile they smile. Cut life fear boy.', 'published': False, 'id': 390, 'created_at': '2022-08-15T20:58:33.653049+00:00', 'owner_id': 4, 'owner': {'id': 4, 'email': 'fastapi12@fastapi.com', 'created_at': '2022-08-15T10:38:51.082905+00:00'}}
# 32  - Post Created
# user9@python.com
# UserName:  user9@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoyMSwiZXhwIjoxNjYwNjAwNzE1fQ.yJ1fQRtKvHhjCW5cbfoTNhELpQrwT219DQ0I171XrCs
# Post Response:  {'title': 'Victoria Wade', 'content': 'Weight former exactly trial. Teacher member simple model off official authority when. Want degree seek best mention might.', 'published': False, 'id': 391, 'created_at': '2022-08-15T20:58:36.309372+00:00', 'owner_id': 21, 'owner': {'id': 21, 'email': 'user9@python.com', 'created_at': '2022-08-15T20:56:52.621254+00:00'}}
# 33  - Post Created
# user3@python.com
# UserName:  user3@python.com   eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxNSwiZXhwIjoxNjYwNjAwNzE4fQ.Pes5gdbe_7vZHgQ471-6LHd89egrrseHRJRhXu67UIU
# Post Response:  {'title': 'Kenneth Kemp', 'content': 'Entire season sign bad top road. Course campaign power why main. She trade federal answer kitchen goal.', 'published': False, 'id': 392, 'created_at': '2022-08-15T20:58:39.207964+00:00', 'owner_id': 15, 'owner': {'id': 15, 'email': 'user3@python.com', 'created_at': '2022-08-15T20:56:37.479528+00:00'}}
# 34  - Post Created
# user2@python.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\WORK\PythonWorks\FastAPI\fastapi\faker.ipynb Cell 1 in <cell line: 2>()
#      <a href='vscode-notebook-cell:/d%3A/WORK/PythonWorks/FastAPI/fastapi/faker.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> post_url = 'https://fastapi-test1-iozberk.herokuapp.com/posts'
#      <a href='vscode-notebook-cell:/d%3A/WORK/PythonWorks/FastAPI/fastapi/faker.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a> login_payload = {'username': f'{random_login_user}','password':'Password1!'}
# ---> <a href='vscode-notebook-cell:/d%3A/WORK/PythonWorks/FastAPI/fastapi/faker.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a> login_response = requests.post(login_url,data= login_payload)
#      <a href='vscode-notebook-cell:/d%3A/WORK/PythonWorks/FastAPI/fastapi/faker.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> access_token = login_response.json()["access_token"]
#      <a href='vscode-notebook-cell:/d%3A/WORK/PythonWorks/FastAPI/fastapi/faker.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a> print("UserName: " ,random_login_user, " " , access_token)
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File d:\WORK\PythonWorks\FastAPI\fastapi\venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
